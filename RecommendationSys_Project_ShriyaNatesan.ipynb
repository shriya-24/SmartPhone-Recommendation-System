# %%
# Importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Importing Data file 1
ph1 = pd.read_csv('DataSets/DataSet/phone_user_review_file_1.csv',encoding = "ISO-8859-1")
ph1.head()
# Out:
#                         phone_url       date lang country            source  \
# 0  /cellphones/samsung-galaxy-s8/   5/2/2017   en      us  Verizon Wireless
# 1  /cellphones/samsung-galaxy-s8/  4/28/2017   en      us       Phone Arena
# 2  /cellphones/samsung-galaxy-s8/   5/4/2017   en      us            Amazon
# 3  /cellphones/samsung-galaxy-s8/   5/2/2017   en      us           Samsung
# 4  /cellphones/samsung-galaxy-s8/  5/11/2017   en      us  Verizon Wireless
#
#                 domain  score  score_max  \
# 0  verizonwireless.com   10.0       10.0
# 1       phonearena.com   10.0       10.0
# 2           amazon.com    6.0       10.0
# 3          samsung.com    9.2       10.0
# 4  verizonwireless.com    4.0       10.0
#
#                                              extract       author  \
# 0  As a diehard Samsung fan who has had every Sam...   CarolAnn35
# 1  Love the phone. the phone is sleek and smooth ...    james0923
# ...

# %%
print("Dimension of Data Set 1: {}".format(ph1.shape))
# Out:
# Dimension of Data Set 1: (374910, 11)

# %%
# Importing Data file 2
ph2 = pd.read_csv('DataSets/DataSet/phone_user_review_file_2.csv',encoding = "ISO-8859-1")
ph2.head()
# Out:
#                     phone_url       date lang country  source        domain  \
# 0  /cellphones/leagoo-lead-7/  4/15/2015   en      us  Amazon    amazon.com
# 1  /cellphones/leagoo-lead-7/  5/23/2015   en      gb  Amazon  amazon.co.uk
# 2  /cellphones/leagoo-lead-7/  4/27/2015   en      gb  Amazon  amazon.co.uk
# 3  /cellphones/leagoo-lead-7/  4/22/2015   en      gb  Amazon  amazon.co.uk
# 4  /cellphones/leagoo-lead-7/  4/18/2015   en      gb  Amazon  amazon.co.uk
#
#    score  score_max                                            extract  \
# 0    2.0       10.0  The telephone headset is of poor quality , not...
# 1   10.0       10.0  This is my first smartphone so I have nothing ...
# 2    8.0       10.0  Great phone. Battery life not great but seems ...
# 3   10.0       10.0      Best 90 quid I've ever spent on a smart phone
# 4   10.0       10.0  I m happy with this phone.it s very good.thx team
#
#           author                                            product
# ...

# %%
print("Dimension of Data Set 2: {}".format(ph2.shape))
# Out:
# Dimension of Data Set 2: (114925, 11)

# %%
# Importing Data file 3
ph3 = pd.read_csv('DataSets/DataSet/phone_user_review_file_3.csv',encoding = "ISO-8859-1")
ph3.head()
# Out:
#                                          phone_url       date lang country  \
# 0  /cellphones/samsung-galaxy-s-iii-slim-sm-g3812/  11/7/2015   pt      br
# 1  /cellphones/samsung-galaxy-s-iii-slim-sm-g3812/  10/2/2015   pt      br
# 2  /cellphones/samsung-galaxy-s-iii-slim-sm-g3812/   9/2/2015   pt      br
# 3  /cellphones/samsung-galaxy-s-iii-slim-sm-g3812/   9/2/2015   pt      br
# 4  /cellphones/samsung-galaxy-s-iii-slim-sm-g3812/   9/1/2015   pt      br
#
#       source            domain  score  score_max  \
# 0  Submarino  submarino.com.br    6.0       10.0
# 1  Submarino  submarino.com.br   10.0       10.0
# 2  Submarino  submarino.com.br   10.0       10.0
# 3  Submarino  submarino.com.br    8.0       10.0
# 4    Colombo    colombo.com.br    8.0       10.0
#
#                                              extract  \
# 0  recomendo, eu comprei um, a um ano, e agora co...
# 1  Comprei um pouco desconfiada do site e do celu...
# ...

# %%
print("Dimension of Data Set 3: {}".format(ph3.shape))
# Out:
# Dimension of Data Set 3: (312961, 11)

# %%
# Importing Data file 4
ph4 = pd.read_csv('DataSets/DataSet/phone_user_review_file_4.csv',encoding = "ISO-8859-1")
ph4.head()
# Out:
#                                     phone_url        date lang country  \
# 0  /cellphones/samsung-s7262-duos-galaxy-ace/   3/11/2015   en      us
# 1  /cellphones/samsung-s7262-duos-galaxy-ace/  17/11/2015   en      in
# 2  /cellphones/samsung-s7262-duos-galaxy-ace/  29/10/2015   en      in
# 3  /cellphones/samsung-s7262-duos-galaxy-ace/  29/10/2015   en      in
# 4  /cellphones/samsung-s7262-duos-galaxy-ace/  29/10/2015   en      in
#
#    source      domain  score  score_max  \
# 0  Amazon  amazon.com    2.0       10.0
# 1  Zopper  zopper.com   10.0       10.0
# 2  Amazon   amazon.in    4.0       10.0
# 3  Amazon   amazon.in    6.0       10.0
# 4  Amazon   amazon.in   10.0       10.0
#
#                                              extract            author  \
# 0  was not conpatable with my phone as stated. I ...  Frances DeSimone
# 1  Decent Functions and Easy to Operate Pros:- Th...     Expert Review
# 2  Not Good Phone such price. Hang too much and v...   Amazon Customer
# ...

# %%
print("Dimension of Data Set 4: {}".format(ph4.shape))
# Out:
# Dimension of Data Set 4: (98284, 11)

# %%
# Importing Data file 5
ph5 = pd.read_csv('DataSets/DataSet/phone_user_review_file_5.csv',encoding = "ISO-8859-1")
ph5.head()
# Out:
#                     phone_url       date lang country      source  \
# 0  /cellphones/karbonn-k1616/  7/13/2016   en      in  91 Mobiles
# 1  /cellphones/karbonn-k1616/  7/13/2016   en      in  91 Mobiles
# 2  /cellphones/karbonn-k1616/  7/13/2016   en      in  91 Mobiles
# 3  /cellphones/karbonn-k1616/  4/25/2014   en      in     Naaptol
# 4  /cellphones/karbonn-k1616/  4/23/2013   en      in     Naaptol
#
#           domain  score  score_max  \
# 0  91mobiles.com    2.0       10.0
# 1  91mobiles.com    6.0       10.0
# 2  91mobiles.com    4.0       10.0
# 3    naaptol.com   10.0       10.0
# 4    naaptol.com   10.0       10.0
#
#                                              extract           author  \
# 0  I bought 1 month before. currently speaker is ...        venkatesh
# 1  I just bought one week back, I have Airtel con...           Venkat
# 2  one problem in this handset opera is not worki...           krrish
# ...

# %%
print("Dimension of Data Set 5: {}".format(ph5.shape))
# Out:
# Dimension of Data Set 5: (350216, 11)

# %%
# Importing Data file 6
ph6 = pd.read_csv('DataSets/DataSet/phone_user_review_file_6.csv',encoding = "ISO-8859-1")
ph6.head()
# Out:
#                                 phone_url        date lang country  \
# 0  /cellphones/samsung-instinct-sph-m800/   9/16/2011   en      us
# 1  /cellphones/samsung-instinct-sph-m800/   2/13/2014   en      us
# 2  /cellphones/samsung-instinct-sph-m800/  12/30/2011   en      us
# 3  /cellphones/samsung-instinct-sph-m800/  10/18/2008   en      us
# 4  /cellphones/samsung-instinct-sph-m800/    9/6/2008   en      us
#
#           source             domain  score  score_max  \
# 0    Phone Arena     phonearena.com    8.0       10.0
# 1         Amazon         amazon.com    6.0       10.0
# 2    Phone Scoop     phonescoop.com    9.0       10.0
# 3  HandCellPhone  handcellphone.com    4.0       10.0
# 4   Reviewed.com       reviewed.com    6.0       10.0
#
#                                              extract      author  \
# 0  I've had the phone for awhile and it's a prett...  ajabrams95
# 1  to be clear it is not the sellers fault that t...   Stephanie
# ...

# %%
print("Dimension of Data Set 6: {}".format(ph6.shape))
# Out:
# Dimension of Data Set 6: (163837, 11)

# %%
print('Check whether the column names are same in all the dataframes: ')
all(np.unique(ph6.columns.tolist()) == np.unique(ph1.columns.tolist()+
                                                      ph2.columns.tolist()+
                                                      ph3.columns.tolist()+
                                                      ph4.columns.tolist()+
                                                      ph5.columns.tolist()+
                                                      ph6.columns.tolist()))
# Out:
# Check whether the column names are same in all the dataframes:
# True

# %% [markdown]
# ### 1.a) Merge all the datasets

# %%
ph_new = pd.concat([ph1, ph2, ph3, ph4, ph5, ph6])
ph_new
# Out:
#                                 phone_url       date lang country  \
# 0          /cellphones/samsung-galaxy-s8/   5/2/2017   en      us
# 1          /cellphones/samsung-galaxy-s8/  4/28/2017   en      us
# 2          /cellphones/samsung-galaxy-s8/   5/4/2017   en      us
# 3          /cellphones/samsung-galaxy-s8/   5/2/2017   en      us
# 4          /cellphones/samsung-galaxy-s8/  5/11/2017   en      us
# ...                                   ...        ...  ...     ...
# 163832  /cellphones/alcatel-ot-club_1187/  5/12/2000   de      de
# 163833  /cellphones/alcatel-ot-club_1187/  5/11/2000   de      de
# 163834  /cellphones/alcatel-ot-club_1187/   5/4/2000   de      de
# 163835  /cellphones/alcatel-ot-club_1187/   5/1/2000   de      de
# 163836  /cellphones/alcatel-ot-club_1187/  4/25/2000   de      de
#
#                   source               domain  score  score_max  \
# 0       Verizon Wireless  verizonwireless.com   10.0       10.0
# ...

# %% [markdown]
# ### 1.b) Check a few observations and shape of the data-frame.

# %%
print("Dimension of the merged Data Set: {}".format(ph_new.shape))
# Out:
# Dimension of the merged Data Set: (1415133, 11)

# %%
ph_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1415133 entries, 0 to 163836
# Data columns (total 11 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   phone_url  1415133 non-null  object
#  1   date       1415133 non-null  object
#  2   lang       1415133 non-null  object
#  3   country    1415133 non-null  object
#  4   source     1415133 non-null  object
#  5   domain     1415133 non-null  object
#  6   score      1351644 non-null  float64
#  7   score_max  1351644 non-null  float64
#  8   extract    1395772 non-null  object
#  9   author     1351931 non-null  object
#  10  product    1415132 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 129.6+ MB

# %% [markdown]
# - Except score and score_max (which are of float type) all other features are of object type
# - Column date should be of datetype
# - score, score_max, extract and author columns seems to have Null values

# %%
print('Number of unique values in each feature: \n',ph_new.nunique())

##score_max for all the phones is 10 throughout
# Out:
# Number of unique values in each feature:
#  phone_url       5556
# date            7728
# lang              22
# country           42
# source           331
# domain           384
# score             86
# score_max          1
# extract      1321353
# author        801103
# product        61313
# dtype: int64

# %%
#Top 10 Non-english users
ph_new[ph_new['lang']!='en']['author'].value_counts(ascending=False)[:10]
# Out:
# Cliente Amazon        19276
# e-bit                  8663
# Client d'Amazon        7613
# Amazon Kunde           4735
# Amazon Customer        2713
# einer Kundin           2610
# einem Kunden           1898
# unknown                1718
# ÐÐ»ÐµÐºÑÐ°Ð½Ð´Ñ     1070
# Ð¡ÐµÑÐ³ÐµÐ¹            904
# Name: author, dtype: int64

# %%
#Top 10 Non-english products
ph_new[ph_new['lang']!='en']['product'].value_counts(ascending=False)[:10]
# Out:
# Huawei P8lite zwart / 16 GB                                                                                                                                                                  2707
# Samsung Galaxy Express I8730                                                                                                                                                                 2686
# Samsung Galaxy S6 zwart / 32 GB                                                                                                                                                              2345
# Nokia 5800 XpressMusic                                                                                                                                                                       1996
# Nokia N95                                                                                                                                                                                    1848
# ...

# %%
# print the frequency count of phone_url column
ph_new['phone_url'].value_counts(ascending=False).head(50)
# Out:
# /cellphones/samsung-galaxy-s-iii/                                 17093
# /cellphones/apple-iphone-5s/                                      16379
# /cellphones/samsung-galaxy-s6/                                    16145
# /cellphones/samsung-galaxy-s5/                                    16082
# /cellphones/samsung-galaxy-s7-edge/                               15917
# /cellphones/motorola-moto-g/                                      14476
# /cellphones/samsung-galaxy-s7-789999/                             13488
# /cellphones/samsung-i9500-galaxy-s-iv/                            13161
# /cellphones/huawei-p8-lite/                                       12629
# /cellphones/lenovo-vibe-k4-note/                                   9662
# /cellphones/samsung-galaxy-s4-mini-gt-i9190-gt-i9192-dual-sim/     9027
# /cellphones/samsung-galaxy-s6-edge-sm-g925f/                       8844
# /cellphones/apple-iphone-4s/                                       8602
# ...

# %% [markdown]
# ### 1.c) Round off scores to the nearest integers.

# %%
ph_new2 = ph_new
ph_new2['score'] = ph_new2['score'].fillna(0)
round(ph_new2['score']).astype(int)
# Out:
# 0         10
# 1         10
# 2          6
# 3          9
# 4          4
#           ..
# 163832     2
# 163833    10
# 163834     2
# 163835     8
# 163836     2
# Name: score, Length: 1415133, dtype: int32

# %% [markdown]
# ### 1.d) Check for missing values. Impute the missing values if there is any

# %%
ph_new2.isnull().sum()
# Out:
# phone_url        0
# date             0
# lang             0
# country          0
# source           0
# domain           0
# score            0
# score_max    63489
# extract      19361
# author       63202
# product          1
# dtype: int64

# %%
ph_new2.describe().transpose()
# Out:
#                count       mean       std   min   25%   50%   75%   max
# score      1415133.0   7.647828  3.047027   0.0   6.0   8.4  10.0  10.0
# score_max  1351644.0  10.000000  0.000000  10.0  10.0  10.0  10.0  10.0

# %%
## Filling score max columns with the median values
ph_new2 = ph_new2.fillna(ph_new2.median())
ph_new2.isnull().sum()
# Out:
# phone_url        0
# date             0
# lang             0
# country          0
# source           0
# domain           0
# score            0
# score_max        0
# extract      19361
# author       63202
# product          1
# dtype: int64

# %%
# dropping the null values in columns 'extract' ,'author' and 'product'
ph_new2 = ph_new2.dropna()

# %%
ph_new2.isnull().sum()
# Out:
# phone_url    0
# date         0
# lang         0
# country      0
# source       0
# domain       0
# score        0
# score_max    0
# extract      0
# author       0
# product      0
# dtype: int64

# %%
ph_new2.shape
# Out:
# (1336416, 11)

# %% [markdown]
# ### 1.e) Check for duplicate values and remove them if there is any

# %%
ph_new2 = ph_new2.drop_duplicates()

# %%
ph_new2.shape
# Out:
# (1331607, 11)

# %% [markdown]
# ### 1.g) Drop irrelevant features. Keep features like Author, Product, and Score.

# %%
ph_new3 = ph_new2
ph_new3.drop(['phone_url','date','lang','country','source','domain','score_max','extract'], axis = 1, inplace = True)
ph_new3.head()
# Out:
#    score       author                                            product
# 0   10.0   CarolAnn35                                  Samsung Galaxy S8
# 1   10.0    james0923                                  Samsung Galaxy S8
# 2    6.0     R. Craig  Samsung Galaxy S8 (64GB) G950U 5.8" 4G LTE Unl...
# 3    9.2  Buster2020                       Samsung Galaxy S8 64GB (AT&T)
# 4    4.0   S Ate Mine                                  Samsung Galaxy S8

# %%
product = ph_new3['product'].value_counts()[:10]
print('Distribution of number of ratings per item (Clipped at 10): \n',product)
sns.barplot(y=product.index,x=product)
plt.tight_layout()
plt.show()
# Out:
# Distribution of number of ratings per item (Clipped at 10):
#  Lenovo Vibe K4 Note (White,16GB)                5223
# Lenovo Vibe K4 Note (Black, 16GB)               4389
# OnePlus 3 (Graphite, 64 GB)                     4103
# OnePlus 3 (Soft Gold, 64 GB)                    3557
# Huawei P8lite zwart / 16 GB                     2707
# Samsung Galaxy Express I8730                    2672
# Lenovo Vibe K5 (Gold, VoLTE update)             2534
# Samsung Galaxy S6 zwart / 32 GB                 2342
# Lenovo Vibe K5 (Grey, VoLTE update)             2108
# Lenovo Used Lenovo Zuk Z1 (Space Grey, 64GB)    1951
# Name: product, dtype: int64

# %%
users = ph_new3['author'].value_counts(dropna=False)[:10]
print('Distribution of number of ratings per user(Clipped at 10): \n',users)
users.index = users.index.map(str)
sns.barplot(y=users.index,x=users)
plt.tight_layout()
plt.show()
# Out:
# Distribution of number of ratings per user(Clipped at 10):
#  Amazon Customer    76933
# Cliente Amazon     19300
# e-bit               8411
# Client d'Amazon     7716
# Amazon Kunde        4746
# Anonymous           2611
# einer Kundin        2610
# einem Kunden        1898
# unknown             1725
# Anonymous           1460
# Name: author, dtype: int64

# %% [markdown]
# ### 1.f) Keep only 1000000 data samples. Use random state=612.

# %%
df = ph_new3.sample(n=1000000, random_state=612)

# %%
df.shape
# Out:
# (1000000, 3)

# %% [markdown]
# ### 2.a) Identify the most rated features.

# %%
#sorting the products which have got highest mean score
df.groupby('product')['score'].mean().sort_values(ascending=False).head()
# Out:
# product
# Samsung J100 Galaxy J1 Smartphone, 4 GB, Marchio TIM, Bianco [Italia]    10.0
# Huawei P10 âAndroid-puhelin Dual-SIM, kulta                            10.0
# Huawei Nova Dual-SIM grey unlocked                                       10.0
# Huawei Nova Plus 32GB Dual-Sim ohne Vertrag grey                         10.0
# Samsung Omnia II i8000 (8GB) Zwart                                       10.0
# Name: score, dtype: float64

# %%
# The product that got most number of reviews.
df['product'].value_counts().head()
# Out:
# Lenovo Vibe K4 Note (White,16GB)     3908
# Lenovo Vibe K4 Note (Black, 16GB)    3234
# OnePlus 3 (Graphite, 64 GB)          3128
# OnePlus 3 (Soft Gold, 64 GB)         2643
# Samsung Galaxy Express I8730         2012
# Name: product, dtype: int64

# %% [markdown]
# ### 2.b) Identify the users with most number of reviews.

# %%
(df['author'].value_counts()).head()
# Out:
# Amazon Customer    57792
# Cliente Amazon     14624
# e-bit               6317
# Client d'Amazon     5698
# Amazon Kunde        3574
# Name: author, dtype: int64

# %% [markdown]
# ### 2.c) Select the data with products having more than 50 ratings and users who have given more than 50 ratings. Report the shape of the final dataset
# - Get the authors who have gave more than 50 ratings
# - Get the products who got more than 50 ratings
# - Get the rows from main dataset where product has more than 50 ratings
# - Find those rows from the extracted rows corresponding to the authors who gave more than 50 ratings

# %%
# extracting authors who gave greater than 50 ratings
df1 = pd.DataFrame(columns=['author', 'a_count'])
df1['author']=df['author'].value_counts().index.tolist() 
df1['a_count'] = list(df['author'].value_counts() > 50)
df1
# Out:
#                  author  a_count
# 0       Amazon Customer     True
# 1        Cliente Amazon     True
# 2                 e-bit     True
# 3       Client d'Amazon     True
# 4          Amazon Kunde     True
# ...                 ...      ...
# 620163       actormodel    False
# 620164             BenP    False
# 620165            pro74    False
# 620166             JOLY    False
# 620167   JasonNMemphis     False
#
# [620168 rows x 2 columns]

# %%
# get names of indexes for which count column value is False
index_names = df1[ df1['a_count'] == False ].index 
# drop these row indexes from dataFrame 
df1.drop(index_names, inplace = True) 
df1
# Out:
#               author  a_count
# 0    Amazon Customer     True
# 1     Cliente Amazon     True
# 2              e-bit     True
# 3    Client d'Amazon     True
# 4       Amazon Kunde     True
# ..               ...      ...
# 669           robert     True
# 670            Carla     True
# 671         Pasquale     True
# 672     Bezlikiy_Djo     True
# 673             Hugo     True
#
# [674 rows x 2 columns]

# %%
# extracting product that got more than 50 ratings
df2 = pd.DataFrame(columns=['product', 'p_count'])
df2['product']=df['product'].value_counts().index.tolist() 
df2['p_count'] = list(df['product'].value_counts() > 50)
df2
# Out:
#                                                  product  p_count
# 0                       Lenovo Vibe K4 Note (White,16GB)     True
# 1                      Lenovo Vibe K4 Note (Black, 16GB)     True
# 2                            OnePlus 3 (Graphite, 64 GB)     True
# 3                           OnePlus 3 (Soft Gold, 64 GB)     True
# 4                           Samsung Galaxy Express I8730     True
# ...                                                  ...      ...
# 55981          Motorola Moto Z Play grijs, zwart / 32 GB    False
# 55982  Smartphone Samsung Galaxy Ace 4 Lite Duos Dual...    False
# 55983                            NOKIA 2310 CEP TELEFONU    False
# 55984  SAMSUNG Marvel Black Unlocked GSM Touch Screen...    False
# 55985                         Nokia X1-01 Dual Sim Phone    False
#
# [55986 rows x 2 columns]

# %%
# get names of indexes for which count column value is False
index_names = df2[ df2['p_count'] == False ].index 
# drop these row indexes from dataFrame 
df2.drop(index_names, inplace = True)
df2
# Out:
#                                                 product  p_count
# 0                      Lenovo Vibe K4 Note (White,16GB)     True
# 1                     Lenovo Vibe K4 Note (Black, 16GB)     True
# 2                           OnePlus 3 (Graphite, 64 GB)     True
# 3                          OnePlus 3 (Soft Gold, 64 GB)     True
# 4                          Samsung Galaxy Express I8730     True
# ...                                                 ...      ...
# 4375  Asus ZenFone 4.5 Smartphone, Storage 8 GB, Ner...     True
# 4376                               Lava Iris X5 (Black)     True
# 4377                                        Sony CMD-C1     True
# 4378  Samsung S5230 Hello Kitty Pink Unlocked GSM Qu...     True
# 4379                                        Nokia 5140i     True
#
# [4380 rows x 2 columns]

# %%
# selecting data rows where product is having more than 50 ratings.  
df3 = df[df['product'].isin(df2['product'])] 
df3
# Out:
#         score            author  \
# 4635     10.0      Dieter Kraft
# 300224   10.0       derrrickman
# 352217    8.0             mario
# 66629     8.0            Darpan
# 77416    10.0   Amazon Customer
# ...       ...               ...
# 167436    6.0           vikaaay
# 179434    8.6          missylee
# 87170     6.0            Sergio
# 281617   10.0  matteo anatrella
# 110878    2.0            Ernest
#
#                                                   product
# 4635    Microsoft Nokia Lumia 630 Single-SIM Smartphon...
# 300224                 Kyocera Kona Black (Virgin Mobile)
# 352217  Samsung G900 Galaxy S5 Smartphone, 16 GB, Nero...
# 66629                 OnePlus One (Sandstone Black, 64GB)
# 77416                         OnePlus 3 (Graphite, 64 GB)
# ...                                                   ...
# 167436                                        Nokia C3-00
# 179434                         Huawei P8 Lite wit / 16 GB
# ...

# %%
# selecting data rows from df3 where author has given more than 50 ratings.
# so that we get the data with products having more than 50 ratings and users who have given more than 50 ratings
df4 = df3[df3['author'].isin(df1['author'])]
df4
# Out:
#         score           author  \
# 352217    8.0            mario
# 77416    10.0  Amazon Customer
# 41513    10.0  Amazon Customer
# 22820     8.0  Amazon Customer
# 34166    10.0          Roberto
# ...       ...              ...
# 177801   10.0   Cliente Amazon
# 21110     2.0  Amazon customer
# 114020   10.0           Nicola
# 160660    8.0   Cliente Amazon
# 87170     6.0           Sergio
#
#                                                   product
# 352217  Samsung G900 Galaxy S5 Smartphone, 16 GB, Nero...
# 77416                         OnePlus 3 (Graphite, 64 GB)
# 41513                  Apple iPhone 5s (Space Grey, 16GB)
# 22820                 Lenovo Vibe K5 (Grey, VoLTE update)
# 34166   LG G3 8806084954985 4G 16GB Black smartphone -...
# ...                                                   ...
# 177801  Huawei P8 lite Smartphone, Display 5.0" IPS, D...
# 21110   Tracfone Motorola Moto E Android Prepaid Phone...
# ...

# %%
#Report the shape of the final dataset.
df4.shape
# Out:
# (108809, 3)

# %% [markdown]
# ### 3) Build a popularity based model and recommend top 5 mobile phones

# %%
#calculating the mean score for a product by grouping it.
ratings_mean_count = pd.DataFrame(df4.groupby('product')['score'].mean())

# %%
#calculating the number of ratings a product got
ratings_mean_count['rating_counts'] = pd.DataFrame(df4.groupby('product')['score'].count())

# %%
#Recommending the 5 mobile phones based in highest mean score and highest number of ratings the product got. 
ratings_mean_count.sort_values(by=['score','rating_counts'], ascending=[False,False]).head()
# Out:
#                                                     score  rating_counts
# product
# Samsung Galaxy Note5                                 10.0             56
# Samsung Galaxy S7 Edge 32Gb                          10.0             13
# Sim Free Apple iPhone SE 64GB Mobile Phone - Sp...   10.0             12
# HTC One (32Gb)                                       10.0             11
# Samsung Galaxy S III, Purple 16GB (Sprint)           10.0              9

# %% [markdown]
# #### If we consider the 1000000 sampled data, we see the different results for 2nd, 3rd, 4th, 5th product positions.

# %%
#calculating the mean score for a product by grouping it.
ratings_mean_count = pd.DataFrame(df.groupby('product')['score'].mean()) 

#calculating the number of ratings a product got
ratings_mean_count['rating_counts'] = pd.DataFrame(df.groupby('product')['score'].count())

#Recommending the 5 mobile phones based in highest mean score and highest number of ratings the product got. 
ratings_mean_count.sort_values(by=['score','rating_counts'], ascending=[False,False]).head()
# Out:
#                                                     score  rating_counts
# product
# Samsung Galaxy Note5                                 10.0            144
# Motorola Smartphone Motorola Moto X Desbloquead...   10.0            143
# Nokia Smartphone Nokia Lumia 520 Desbloqueado O...   10.0            129
# Motorola Smartphone Motorola Moto G Dual Chip D...   10.0            126
# Motorola Smartphone Motorola Novo Moto G DTV Co...   10.0            119

# %% [markdown]
# ### 4.a) Build a collaborative filtering model using SVD. You can use SVD from surprise or build it from scratch(Note: Incase you’re building it from scratch you can limit your data points to 5000 samples if you face memory issues).

# %%
from surprise import SVD
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
from surprise.model_selection import cross_validate
from surprise.model_selection import train_test_split

# Suppressing Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
collab1 = df4.copy()
collab1.shape
# Out:
# (108809, 3)

# %% [markdown]
# - We will be using the same trainset and testset for SVD, KNN(user based) and (item based)
# - We will fit the model, use it for predictions, calculate the RMSE
# - After doing for all three we will compare the RMSE values

# %%
# Rearrange columns for SVD and prepare train and testsets
collab2 = Dataset.load_from_df(collab1[['author','product','score']], Reader(rating_scale=(1, 10)))
trainset, testset = train_test_split(collab2, test_size=.25,random_state=612)

print('top 3 values from trainset: \n')
for key,value in {k: v for k, v in trainset.ur.items() if k <= 2}.items(): print(key,'-> ',value,'\n')
print('\ntop 3 values from testset: ', *testset[0:3], sep='\n\n')
# Out:
# top 3 values from trainset:
#
# ...

# %%
# fit and predict using svd
def svd_func(train, test):
    svd = SVD(random_state=612)
    svd.fit(train)
    svd_pred = svd.test(test)
    return svd_pred, svd

svd_pred, svd = svd_func(trainset,testset)
print('First few prediction values: \n',svd_pred[0:2])
print('\nRMSE value(SVD model): ',round(accuracy.rmse(svd_pred),2),'\n') # compute RMSE
svd_rmse = round(accuracy.rmse(svd_pred),2)
# Out:
# First few prediction values:
#  [Prediction(uid='michael', iid='Microsoft Nokia 515 DE Smartphone ( 6,1 cm (2,4 Zoll) Farbdisplay, 5 Megapixel Digitalkamera, Bluetooth 3.0) schwarz', r_ui=10.0, est=8.555564549356681, details={'was_impossible': False}), Prediction(uid='Elena', iid='Huawei P8 Champagne / 16 GB', r_ui=9.0, est=7.945133461383276, details={'was_impossible': False})]
# RMSE: 2.7997
#
# RMSE value(SVD model):  2.8
#
# RMSE: 2.7997

# %% [markdown]
# ### 4.b) Build a collaborative filtering model using kNNWithMeans from surprise. (user-based model)

# %%
# fit and predict using knn
def knn_user(train, test):
    knn_u = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': True})
    knn_u.fit(train)
    knn_u_pred = knn_u.test(test)
    return knn_u_pred, knn_u

# %%
knn_u_pred, knn_u = knn_user(trainset, testset)
print('First few prediction values: \n',knn_u_pred[0:2])
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# First few prediction values:
#  [Prediction(uid='michael', iid='Microsoft Nokia 515 DE Smartphone ( 6,1 cm (2,4 Zoll) Farbdisplay, 5 Megapixel Digitalkamera, Bluetooth 3.0) schwarz', r_ui=10.0, est=5.256792958285495, details={'actual_k': 1, 'was_impossible': False}), Prediction(uid='Elena', iid='Huawei P8 Champagne / 16 GB', r_ui=9.0, est=8.351098853983398, details={'actual_k': 8, 'was_impossible': False})]

# %%
print('\nRMSE value(Knn-User-based Model, test-set): ',round(accuracy.rmse(knn_u_pred),2),'\n') # compute RMSE
knn_u_rmse = round(accuracy.rmse(knn_u_pred),2)
# Out:
# RMSE: 2.8815
#
# RMSE value(Knn-User-based Model, test-set):  2.88
#
# RMSE: 2.8815

# %% [markdown]
# ### 4.c) Build a collaborative filtering model using kNNWithMeans from surprise. (item-based model)

# %%
# fit and predict using knn
def knn_item(train, test):
    knn_i = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': False})
    knn_i.fit(train)
    knn_i_pred = knn_i.test(test)
    return knn_i_pred, knn_i

# %%
knn_i_pred, knn_i = knn_item(trainset, testset)
print('First few prediction values: \n',knn_i_pred[0:2])
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# First few prediction values:
#  [Prediction(uid='michael', iid='Microsoft Nokia 515 DE Smartphone ( 6,1 cm (2,4 Zoll) Farbdisplay, 5 Megapixel Digitalkamera, Bluetooth 3.0) schwarz', r_ui=10.0, est=6.076525337346768, details={'actual_k': 4, 'was_impossible': False}), Prediction(uid='Elena', iid='Huawei P8 Champagne / 16 GB', r_ui=9.0, est=8.7739738539648, details={'actual_k': 13, 'was_impossible': False})]

# %%
print('\nRMSE value(Knn-Item-based Model, test-set): ',round(accuracy.rmse(knn_i_pred),2),'\n') # compute RMSE
knn_i_rmse = round(accuracy.rmse(knn_i_pred),2)
# Out:
# RMSE: 2.8239
#
# RMSE value(Knn-Item-based Model, test-set):  2.82
#
# RMSE: 2.8239

# %% [markdown]
# ### 5. Evaluate the collaborative model. Print RMSE value

# %%
#Comparison of RMSE scores
sns.barplot(x=['svd_rmse','knn_item_rmse', 'knn_user_rmse'],y=[svd_rmse,knn_i_rmse, knn_u_rmse])
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see all three are quite close, best is SVD with RMSE of 2.7997

# %% [markdown]
# ### 6. Predict score (average rating) for test users.

# %%
svd_pred_df=pd.DataFrame(svd_pred, columns=['uid', 'iid', 'rui', 'est', 'details'])
print('average prediction for test users: ',svd_pred_df['est'].mean())
print('average rating  by test users: ',svd_pred_df['rui'].mean())
print('average prediction error for test users: ',(svd_pred_df['rui']-svd_pred_df['est']).abs().mean())
# Out:
# average prediction for test users:  7.506983276159134
# average rating  by test users:  7.459162592361123
# average prediction error for test users:  2.1991428945162337

# %%
knn_u_pred_df=pd.DataFrame(knn_u_pred, columns=['uid', 'iid', 'rui', 'est', 'details'])
print('average prediction for test users: ',knn_u_pred_df['est'].mean())
print('average rating  by test users: ',knn_u_pred_df['rui'].mean())
print('average prediction error for test users: ',(knn_u_pred_df['rui']-knn_u_pred_df['est']).abs().mean())
# Out:
# average prediction for test users:  7.490268859041193
# average rating  by test users:  7.459162592361123
# average prediction error for test users:  2.20888287751977

# %%
knn_i_pred_df=pd.DataFrame(knn_i_pred, columns=['uid', 'iid', 'rui', 'est', 'details'])
print('average prediction for test users: ',knn_i_pred_df['est'].mean())
print('average rating  by test users: ',knn_i_pred_df['rui'].mean())
print('average prediction error for test users: ',(knn_i_pred_df['rui']-knn_i_pred_df['est']).abs().mean())
# Out:
# average prediction for test users:  7.465585790409615
# average rating  by test users:  7.459162592361123
# average prediction error for test users:  2.1930712308123046

# %% [markdown]
# As we can see, The average rating by test users and the average prediction is the closeset for the knn item based model
#
# This explains its least prediction error among all the 3 models.

# %% [markdown]
# ### 7. Report your findings and inferences.

# %% [markdown]
# - Samsung Galaxy Note 5 is a highly recommended phone from the popularity based model.
# - Most of the authors have given the rating of '10' or '8'
# - All 3 algorithms have a very close RMSE value.
# - Overall data is highly skewed towards 'Amazon customers' from different countries.
# - Since Amazon is a leading giant in selling smartphones many users are realted to amazon but usernames are not correct.
# - Many unknown users and anonymous users exist which seem to take a large chunk of the data.

# %% [markdown]
# ### 8. Try and recommend top 5 products for test users

# %%
from collections import defaultdict
def get_top_n(predictions, n=5):
    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

# %%
top_5 = get_top_n(svd_pred,5)
print('Top 5 recommendations for all test users (using the SVD MODEL) are: ')
for key,value in top_5.items(): print('User : ',key,'--->',value,'\n')
# Out:
# Top 5 recommendations for all test users (using the SVD MODEL) are:
# User :  michael ---> [('HTC ONE M8 5" 16GB 4G LTE ANDROID 4.4 EUROPA GRAY', 9.326107210257538), ('Alcatel OneTouch Idol 3 Global Unlocked 4G LTE Smartphone, 5.5 HD IPS Display, 16GB (GSM - US Warranty)', 9.32366939768644), ('Microsoft Lumia 640 5 inch SIM-Free Smartphone - Black', 8.972622625568997), ('Vodafone Smart Prime 6 Pay As You Go Handset Smartphone - Anthracite', 8.844032793893353), ('Samsung Galaxy S5 Active G870a 16GB Unlocked GSM Extremely Durable Smartphone w/ 16MP Camera - Titanium Gray', 8.778952852251239)]
#
# ...

# %%
top_5 = get_top_n(knn_u_pred,5)
print('Top 5 recommendations for all test users (using the Knn user based MODEL) are: ')
for key,value in top_5.items(): print('User : ',key,'--->',value,'\n')
# Out:
# Top 5 recommendations for all test users (using the Knn user based MODEL) are:
# User :  michael ---> [('HTC ONE M8 5" 16GB 4G LTE ANDROID 4.4 EUROPA GRAY', 9.816622022613437), ('Alcatel OneTouch Idol 3 Global Unlocked 4G LTE Smartphone, 5.5 HD IPS Display, 16GB (GSM - US Warranty)', 9.565720611771093), ('Samsung Galaxy S5 Active G870a 16GB Unlocked GSM Extremely Durable Smartphone w/ 16MP Camera - Titanium Gray', 8.666666666666666), ('Microsoft Lumia 640 5 inch SIM-Free Smartphone - Black', 8.666666666666666), ('Vodafone Smart Prime 6 Pay As You Go Handset Smartphone - Anthracite', 8.666666666666666)]
#
# ...

# %%
top_5 = get_top_n(knn_i_pred,5)
print('Top 5 recommendations for all test users (using the Knn item based MODEL) are: ')
for key,value in top_5.items(): print('User : ',key,'--->',value,'\n')
# Out:
# Top 5 recommendations for all test users (using the Knn item based MODEL) are:
# User :  michael ---> [('HTC ONE M8 5" 16GB 4G LTE ANDROID 4.4 EUROPA GRAY', 9.419333748419504), ('Vodafone Smart Prime 6 Pay As You Go Handset Smartphone - Anthracite', 9.291575043155232), ('Microsoft Lumia 640 5 inch SIM-Free Smartphone - Black', 8.479095053587935), ('Alcatel OneTouch Idol 3 Global Unlocked 4G LTE Smartphone, 5.5 HD IPS Display, 16GB (GSM - US Warranty)', 8.4015160421657), ('Samsung Galaxy S5 Active G870a 16GB Unlocked GSM Extremely Durable Smartphone w/ 16MP Camera - Titanium Gray', 7.701147402655112)]
#
# ...

# %% [markdown]
# - User :  michael ---> [('HTC ONE M8 5" 16GB 4G LTE ANDROID 4.4 EUROPA GRAY', 9.326107210257538), ('Alcatel OneTouch Idol 3 Global Unlocked 4G LTE Smartphone, 5.5 HD IPS Display, 16GB (GSM - US Warranty)', 9.32366939768644), ('Microsoft Lumia 640 5 inch SIM-Free Smartphone - Black', 8.972622625568997), ('Vodafone Smart Prime 6 Pay As You Go Handset Smartphone - Anthracite', 8.844032793893353), ('Samsung Galaxy S5 Active G870a 16GB Unlocked GSM Extremely Durable Smartphone w/ 16MP Camera - Titanium Gray', 8.778952852251239)]
#
#
# - User :  michael ---> [('HTC ONE M8 5" 16GB 4G LTE ANDROID 4.4 EUROPA GRAY', 9.816622022613437), ('Alcatel OneTouch Idol 3 Global Unlocked 4G LTE Smartphone, 5.5 HD IPS Display, 16GB (GSM - US Warranty)', 9.565720611771093), ('Samsung Galaxy S5 Active G870a 16GB Unlocked GSM Extremely Durable Smartphone w/ 16MP Camera - Titanium Gray', 8.666666666666666), ('Microsoft Lumia 640 5 inch SIM-Free Smartphone - Black', 8.666666666666666), ('Vodafone Smart Prime 6 Pay As You Go Handset Smartphone - Anthracite', 8.666666666666666)]
#
#
# - User :  michael ---> [('HTC ONE M8 5" 16GB 4G LTE ANDROID 4.4 EUROPA GRAY', 9.419333748419504), ('Vodafone Smart Prime 6 Pay As You Go Handset Smartphone - Anthracite', 9.291575043155232), ('Microsoft Lumia 640 5 inch SIM-Free Smartphone - Black', 8.479095053587935), ('Alcatel OneTouch Idol 3 Global Unlocked 4G LTE Smartphone, 5.5 HD IPS Display, 16GB (GSM - US Warranty)', 8.4015160421657), ('Samsung Galaxy S5 Active G870a 16GB Unlocked GSM Extremely Durable Smartphone w/ 16MP Camera - Titanium Gray', 7.701147402655112)]
#
#
# As you can see, all the 3 models recommended the same 5 phones to the user micheal in different orders as per user based or item based model use case scenario it will be used for.

# %% [markdown]
# ### 9. Try cross validation techniques to get better results.

# %%
svd_cv = cross_validate(svd,collab2, measures=['RMSE'], cv=3, verbose=False)
print('\n Mean svd cv score:', round(svd_cv['test_rmse'].mean(),2),'\n')
svd_cv
# Out:
#  Mean svd cv score: 2.82
# {'test_rmse': array([2.81863239, 2.8188021 , 2.81017972]),
#  'fit_time': (6.649857997894287, 6.312112808227539, 5.879236936569214),
#  'test_time': (0.4557816982269287, 0.3341062068939209, 0.505648136138916)}

# %%
knn_u_cv = cross_validate(knn_u,collab2, measures=['RMSE'], cv=3, verbose=False)
print('\n Mean knn_u_cv score:', round(knn_u_cv['test_rmse'].mean(),2),'\n')
knn_u_cv
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
#
#  Mean knn_u_cv score: 2.89
# {'test_rmse': array([2.90669951, 2.88526171, 2.87708295]),
#  'fit_time': (2.674051284790039, 2.47642183303833, 2.18866229057312),
#  'test_time': (8.489214420318604, 8.438431739807129, 8.385594606399536)}

# %%
knn_i_cv = cross_validate(knn_i,collab2, measures=['RMSE'], cv=3, verbose=False)
print('\n Mean knn_i_cv score:', round(knn_i_cv['test_rmse'].mean(),2),'\n')
knn_i_cv
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
#
#  Mean knn_i_cv score: 2.83
# {'test_rmse': array([2.83385572, 2.83142208, 2.83682927]),
#  'fit_time': (157.72998905181885, 186.1116235256195, 187.04035544395447),
#  'test_time': (453.3980083465576, 547.3785152435303, 452.7160577774048)}

# %%
# Comparison of RMSE scores(mean cv) from different collaorative algorithms
sns.barplot(y=[svd_cv['test_rmse'].mean(),knn_u_cv['test_rmse'].mean(), knn_i_cv['test_rmse'].mean()],
            x=['svd_cv_rmse','knn_user_cv_rmse', 'knn_item_cv_rmse'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Cross validation did not much affect the RMSE values. It was kind of almost similar to without CV.
# - Only in case of SVD it worsened by 0.02 by doing a CV.

# %% [markdown]
# ### 10. In what business scenario you should use popularity based Recommendation Systems?

# %% [markdown]
# Popularity based recommendation system relies on the popularity, trends and frequency counts of which items were most purchased.
#
# It is used buy the travel companies selling holiday packages in a season, by Google News and other news websites to show Top Stories with images
#
# Popularity based recommendation systems can be useful in multiple scenarios like:
#
# - When there is no data about the user and items.
# - When it is required to show most popular items in different categories along with personalized results like:
#     - Most popular trend in western wear clothes or traditional wear clothes.
#     - Most popular hindi songs or most popular english songs on a music website/app.
#     - Most popular dishes of the restaurant (Recommended dishes in swiggy)
#     - Most popular holiday packages for hiking trips, or bike trips or himalayan trips etc.

# %% [markdown]
# ### 11. In what business scenario you should use CF based Recommendation Systems?

# %% [markdown]
# Collaborative Filtering is used to building intelligent recommender systems that can learn to give better recommendations as more information about users is collected.
#
# It is a personalised recommender system , recommendations are made based on the past behaviour of the user.
#
# Most websites like Amazon, YouTube, and Netflix use collaborative filtering as a part of their sophisticated recommendation system.
#
# Collaborative filtering is useful in scenarios like:
#
# - Giving personalised recommendation to the user, when user history or item data is available.
# - Some examples can be:
#     - Personalized movie recommendation of movie sites like Netflix, Amazon Prime, Youtube etc

# %% [markdown]
# ### 12. What other possible methods can you think of which can further improve the recommendation for different users?

# %% [markdown]
# Content-based,
# Demographic,
# Utility based,
# Knowledge based,
# Hybrid recommendation system (like Content+Collaborative) methods can be used as per the user needs.
